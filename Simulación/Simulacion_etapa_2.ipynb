# %%
### leer base de datos de la etapa anterior: 'etapa_1.db'

import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('etapa_1.db')
cursor = conn.cursor()

# Seleccionar todos los registros de la tabla 'lotes'
cursor.execute('SELECT * FROM lotes')
lotes = []
# Iterar sobre los resultados y imprimirlos
for lote in cursor.fetchall():
    lote = list(lote)
    lotes.append(lote)

# Cerrar la conexión
conn.close()

# %%
print(lotes)
# Out:
# [[1, 'L_1_C4', 1, 'C4', 217.5, 116, 0.43, 0.39, 0.257, -2, 0.9899548001959183], [2, 'L_2_C4', 2, 'C4', 517.5, 121, 0.35, 0.44, 0.269, -2, 0.9459791828040489], [3, 'L_3_C6', 3, 'C6', 450.0, 80, 0.46, 0.38, 0.362, 1, 0.9666273092054694], [4, 'L_4_C4', 4, 'C4', 168.75, 126, 0.32, 0.51, 0.276, 4, 0.9817061224489796], [5, 'L_5_C6', 5, 'C6', 243.75, 104, 0.49, 0.6, 0.348, 0, 0.9537016248860255], [6, 'L_6_C3', 6, 'C3', 150.0, 95, 0.31, 0.56, 0.579, -1, 0.941094], [7, 'L_7_C5', 7, 'C5', 558.75, 109, 0.43, 0.39, 0.795, 0, 0.96032425], [8, 'L_8_C6', 8, 'C6', 442.5, 74, 0.38, 0.35, 0.36, -4, 0.9496173673469388], [9, 'L_9_C1', 9, 'C1', 300.0, 124, 0.36, 0.35, 0.528, -1, 0.9419898962066326], [10, 'L_10_C5', 10, 'C5', 108.75, 79, 0.5, 0.56, 0.806, 0, 0.941117765], [11, 'L_11_C1', 11, 'C1', 555.0, 99, 0.31, 0.53, 0.557, -1, 0.95648355], [12, 'L_12_C1', 12, 'C1', 412.5, 124, 0.41, 0.33, 0.516, 0, 0.96032425], [13, 'L_13_C5', 13, 'C5', 547.5, 89, 0.5, 0.48, 0.811, 0, 0.9364121761749999], [14, 'L_14_C2', 14, 'C2', 498.75, 113, 0.44, 0.52, 0.416, -3, 0.9664506766365126], [15, 'L_15_C1', 15, 'C1', 101.25, 127, 0.31, 0.48, 0.554, 0, 1.0], [16, 'L_16_C6', 16, 'C6', 502.5, 97, 0.47, 0.34, 0.361, 0, 0.998], [17, 'L_17_C5', 17, 'C5', 536.25, 112, 0.45, 0.39, 0.82, -1, 0.9722387462716836], [18, 'L_18_C2', 18, 'C2', 247.5, 91, 0.37, 0.43, 0.407, 0, 1.0], [19, 'L_19_C2', 19, 'C2', 457.5, 82, 0.39, 0.41, 0.413, 1, 0.9971853061224489], [20, 'L_20_C4', 20, 'C4', 225.0, 75, 0.33, 0.41, 0.274, 1, 0.9850178530612245], [21, 'L_21_C5', 21, 'C5', 427.5, 74, 0.36, 0.35, 0.828, -1, 0.957384481887755], [22, 'L_22_C1', 22, 'C1', 420.0, 74, 0.39, 0.35, 0.554, 2, 0.9751], [23, 'L_23_C3', 23, 'C3', 262.5, 97, 0.42, 0.39, 0.601, 2, 0.9557469387755102], [24, 'L_24_C5', 24, 'C5', 363.75, 114, 0.49, 0.55, 0.808, -1, 0.9623938499999999], [25, 'L_25_C3', 25, 'C3', 168.75, 121, 0.45, 0.46, 0.588, -1, 0.9602999999999999], [26, 'L_26_C6', 26, 'C6', 442.5, 124, 0.38, 0.54, 0.356, 1, 0.9914126248261224], [27, 'L_27_C6', 27, 'C6', 168.75, 121, 0.49, 0.52, 0.361, 0, 0.992019984], [28, 'L_28_C3', 28, 'C3', 382.5, 94, 0.42, 0.48, 0.596, 2, 0.9464084586], [29, 'L_29_C1', 29, 'C1', 285.0, 78, 0.37, 0.56, 0.549, -3, 0.9221072645408163], [30, 'L_30_C4', 30, 'C4', 101.25, 74, 0.5, 0.39, 0.273, -1, 0.9701129776530611], [31, 'L_31_C1', 31, 'C1', 307.5, 120, 0.36, 0.32, 0.544, 0, 0.941117765], [33, 'L_33_C6', 33, 'C6', 303.75, 103, 0.34, 0.55, 0.344, 3, 0.9615910454693878], [34, 'L_34_C2', 34, 'C2', 135.0, 78, 0.48, 0.41, 0.403, 2, 0.9813957240816327], [35, 'L_35_C5', 35, 'C5', 341.25, 120, 0.41, 0.33, 0.828, 3, 0.9291735413265306], [36, 'L_36_C6', 36, 'C6', 450.0, 83, 0.47, 0.34, 0.36, 1, 0.9834494712130611], [37, 'L_37_C6', 37, 'C6', 330.0, 95, 0.38, 0.51, 0.345, -1, 0.9899954534204082], [38, 'L_38_C1', 38, 'C1', 183.75, 103, 0.47, 0.38, 0.544, 3, 0.9653489999999999], [39, 'L_39_C6', 39, 'C6', 161.25, 79, 0.32, 0.52, 0.357, -1, 0.9691181632653061], [40, 'L_40_C1', 40, 'C1', 146.25, 91, 0.5, 0.34, 0.533, -1, 0.9515049456632653], [42, 'L_42_C4', 42, 'C4', 352.5, 129, 0.32, 0.35, 0.259, 0, 0.9840519520000001], [43, 'L_43_C1', 43, 'C1', 108.75, 123, 0.44, 0.33, 0.531, 1, 0.9507210074999999], [44, 'L_44_C2', 44, 'C2', 367.5, 76, 0.44, 0.6, 0.412, 0, 0.990035944032], [45, 'L_45_C4', 45, 'C4', 498.75, 87, 0.32, 0.38, 0.27, -2, 0.9939265306122449], [46, 'L_46_C4', 46, 'C4', 446.25, 127, 0.4, 0.43, 0.267, 0, 0.9633195], [47, 'L_47_C2', 47, 'C2', 225.0, 93, 0.49, 0.42, 0.396, 1, 0.9931965648979592], [48, 'L_48_C1', 48, 'C1', 461.25, 99, 0.39, 0.34, 0.541, -2, 0.94844395], [49, 'L_49_C5', 49, 'C5', 412.5, 108, 0.41, 0.43, 0.831, -1, 0.9576060621106248], [50, 'L_50_C5', 50, 'C5', 540.0, 114, 0.36, 0.42, 0.781, 1, 0.9869943112244897], [51, 'L_51_C1', 51, 'C1', 412.5, 104, 0.4, 0.36, 0.526, 1, 0.97522412625], [52, 'L_52_C2', 52, 'C2', 450.0, 86, 0.49, 0.49, 0.406, 2, 0.9794329326334694], [53, 'L_53_C6', 53, 'C6', 247.5, 83, 0.43, 0.32, 0.345, -1, 0.9781155079793632], [54, 'L_54_C2', 54, 'C2', 307.5, 80,  ...

# %%
# parametros de la simulacion etapa 2
